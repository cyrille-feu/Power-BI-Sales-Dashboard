# %% [markdown]
# ## Presentation of different results obtained in our study

# %% [markdown]
# The goal of this notebook is to show a sales dashboard build in power BI:

# %% [markdown]
# ### Part 1: About the dataset

# %% [markdown]
# The original dataset consists of 4 different excels files.

# %%
from IPython.display import Image
Image('img/data.png',width=400)

# %% [markdown]
# Each of these excels files is compose of different column an rows. the figures below show the description and the shape of each file

# %% [markdown]
# #### Sales data

# %%
from IPython.display import Image
Image('img/sales data.png',width=800)

# %% [markdown]
# #### Budget data

# %%
from IPython.display import Image
Image('img/budget data.png',width=900)

# %% [markdown]
# #### products data

# %%
from IPython.display import Image
Image('img/proucts data.png',width=500)

# %% [markdown]
# ### Part 2: Results

# %% [markdown]
# #### Home page

# %% [markdown]
# From the home page, we can see the summary of each year by clicking on the corresponding year. we also have two buttons where we can click and directly access the sales or ranking page

# %%
from IPython.display import Image
Image('img/home.png',width=900)

# %% [markdown]
# ####  Sales page

# %%
from IPython.display import Image
Image('img/sales.png',width=900)

# %% [markdown]
# From this page, we can enable multiple functionalities. one of them is the filter to find a specific result.

# %%
from IPython.display import Image
Image('img/filter.png',width=900)

# %% [markdown]
# We can also show the light mode by clicking on the light.

# %%
from IPython.display import Image
Image('img/light mode.png',width=900)

# %% [markdown]
# The mouse cursor can be placed on the corresponding quarter to show the comparison between the budget and the revenue.

# %%
from IPython.display import Image
Image('img/revenu vs budget.png',width=900)

# %% [markdown]
# We can also see the image of a specific product

# %%
from IPython.display import Image
Image('img/products.png',width=900)

# %% [markdown]
# ####  Ranking page

# %%
from IPython.display import Image
Image('img/ranking.png',width=900)
